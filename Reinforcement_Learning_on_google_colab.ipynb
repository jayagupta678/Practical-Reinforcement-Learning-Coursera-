# %% [markdown]
# <a href="https://colab.research.google.com/github/jayagupta678/Practical-Reinforcement-Learning-Coursera-/blob/master/Reinforcement_Learning_on_google_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get update && apt-get install -y python-numpy python-dev cmake zlib1g-dev libjpeg-dev xvfb ffmpeg xorg-dev python-opengl libboost-all-dev libsdl2-dev swig
# Out:
# Ign:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1710/x86_64  InRelease
# Ign:2 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1604/x86_64  InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1710/x86_64  Release
# Hit:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1604/x86_64  Release
# Hit:5 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:7 http://security.ubuntu.com/ubuntu bionic-security InRelease [83.2 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:12 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [227 kB]
# Get:13 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [104 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-updates/universe Sources [115 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [709 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [512 kB]
# Fetched 1,913 kB in 2s (770 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libjpeg-dev is already the newest version (8c-2ubuntu8).
# libjpeg-dev set to manually installed.
# python-dev is already the newest version (2.7.15~rc1-1).
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-0ubuntu2).
# zlib1g-dev set to manually installed.
# The following additional packages will be installed:
#   autotools-dev cmake-data file fontconfig freeglut3 gir1.2-ibus-1.0
#   i965-va-driver ibverbs-providers libaacs0 libarchive13 libasound2
#   libasound2-data libasound2-dev libass9 libasyncns0 libavc1394-0 libavcodec57
#   libavdevice57 libavfilter6 libavformat57 libavresample3 libavutil55
#   libbdplus0 libbluray2 libboost-atomic-dev libboost-atomic1.65-dev
#   libboost-atomic1.65.1 libboost-chrono-dev libboost-chrono1.65-dev
#   libboost-chrono1.65.1 libboost-container-dev libboost-container1.65-dev
#   libboost-container1.65.1 libboost-context-dev libboost-context1.65-dev
#   libboost-context1.65.1 libboost-coroutine-dev libboost-coroutine1.65-dev
#   libboost-coroutine1.65.1 libboost-date-time-dev libboost-date-time1.65-dev
#   libboost-date-time1.65.1 libboost-dev libboost-exception-dev
#   libboost-exception1.65-dev libboost-fiber-dev libboost-fiber1.65-dev
#   libboost-fiber1.65.1 libboost-filesystem-dev libboost-filesystem1.65-dev
#   libboost-filesystem1.65.1 libboost-graph-dev libboost-graph-parallel-dev
#   libboost-graph-parallel1.65-dev libboost-graph-parallel1.65.1
#   libboost-graph1.65-dev libboost-graph1.65.1 libboost-iostreams-dev
#   libboost-iostreams1.65-dev libboost-iostreams1.65.1 libboost-locale-dev
#   libboost-locale1.65-dev libboost-locale1.65.1 libboost-log-dev
#   libboost-log1.65-dev libboost-log1.65.1 libboost-math-dev
#   libboost-math1.65-dev libboost-math1.65.1 libboost-mpi-dev
#   libboost-mpi-python-dev libboost-mpi-python1.65-dev
#   libboost-mpi-python1.65.1 libboost-mpi1.65-dev libboost-mpi1.65.1
#   libboost-numpy-dev libboost-numpy1.65-dev libboost-numpy1.65.1
#   libboost-program-options-dev libboost-program-options1.65-dev
#   libboost-program-options1.65.1 libboost-python-dev libboost-python1.65-dev
#   libboost-python1.65.1 libboost-random-dev libboost-random1.65-dev
#   libboost-random1.65.1 libboost-regex-dev libboost-regex1.65-dev
#   libboost-regex1.65.1 libboost-serialization-dev
#   libboost-serialization1.65-dev libboost-serialization1.65.1
#   libboost-signals-dev libboost-signals1.65-dev libboost-signals1.65.1
#   libboost-stacktrace-dev libboost-stacktrace1.65-dev
#   libboost-stacktrace1.65.1 libboost-system-dev libboost-system1.65-dev
#   libboost-system1.65.1 libboost-test-dev libboost-test1.65-dev
#   libboost-test1.65.1 libboost-thread-dev libboost-thread1.65-dev
#   libboost-thread1.65.1 libboost-timer-dev libboost-timer1.65-dev
#   libboost-timer1.65.1 libboost-tools-dev libboost-type-erasure-dev
#   libboost-type-erasure1.65-dev libboost-type-erasure1.65.1 libboost-wave-dev
#   libboost-wave1.65-dev libboost-wave1.65.1 libboost1.65-dev
#   libboost1.65-tools-dev libbs2b0 libcaca0 libcairo2 libcapnp-0.6.1
#   libcdio-cdda2 libcdio-paranoia2 libcdio17 libchromaprint1 libcroco3
#   libcrystalhd3 libdatrie1 libdbus-1-dev libdc1394-22 libdmx-dev libdmx1
#   libdrm-amdgpu1 libdrm-dev libdrm-intel1 libdrm-nouveau2 libdrm-radeon1
#   libegl1-mesa-dev libfabric1 libfftw3-double3 libflac8 libflite1
#   libfontenc-dev libfontenc1 libfribidi0 libfs-dev libfs6 libgdk-pixbuf2.0-0
#   libgdk-pixbuf2.0-bin libgdk-pixbuf2.0-common libgl1 libgl1-mesa-dev
#   libgl1-mesa-dri libgles1 libgles2-mesa-dev libglu1-mesa libglu1-mesa-dev
#   libglvnd-core-dev libglvnd-dev libglx-mesa0 libglx0 libgme0 libgsm1
#   libhwloc-dev libhwloc-plugins libhwloc5 libibus-1.0-5 libibus-1.0-dev
#   libibverbs-dev libibverbs1 libice-dev libiec61883-0 libjack-jackd2-0
#   libjbig0 libjsoncpp1 libllvm6.0 libltdl-dev libltdl7 liblzo2-2 libmagic-mgc
#   libmagic1 libmirclient-dev libmirclient9 libmircommon-dev libmircommon7
#   libmircookie-dev libmircookie2 libmircore-dev libmircore1 libmirprotobuf3
#   libmp3lame0 libmpg123-0 libmysofa0 libnl-3-200 libnl-route-3-200 libnuma-dev
#   libnuma1 libogg0 libopenal-data libopenal1 libopenjp2-7 libopenmpi-dev
#   libopenmpi2 libopenmpt0 libopus0 libpango-1.0-0 libpangocairo-1.0-0
#   libpangoft2-1.0-0 libpciaccess-dev libpciaccess0 libpixman-1-0
#   libpixman-1-dev libpostproc54 libprotobuf-dev libprotobuf-lite10
#   libprotobuf10 libpsm-infinipath1 libpulse-dev libpulse-mainloop-glib0
#   libpulse0 libraw1394-11 librdmacm1 librhash0 librsvg2-2 librsvg2-common
#   librubberband2 libsamplerate0 libsdl2-2.0-0 libsensors4 libshine3 libslang2
#   libsm-dev libsnappy1v5 libsndfile1 libsndio-dev libsndio6.1 libsoxr0
#   libspeex1 libssh-gcrypt-4 libswresample2 libswscale4 libthai-data libthai0
#   libtheora0 libtiff5 libtool libtwolame0 libudev-dev libusb-1.0-0 libuv1
#   libva-drm2 libva-x11-2 libva2 libvdpau1 libvorbis0a libvorbisenc2
#   libvorbisfile3 libvpx5 libwavpack1 libwayland-bin libwayland-cursor0
#   libwayland-dev libwayland-egl1-mesa libwebp6 libwebpmux3 libwrap0
#   libx11-xcb-dev libx264-152 libx265-146 libxaw7 libxaw7-dev libxcb-dri2-0-dev
#   libxcb-dri3-dev libxcb-glx0 libxcb-glx0-dev libxcb-present-dev libxcb-randr0
#   libxcb-randr0-dev libxcb-render0 libxcb-render0-dev libxcb-shape0
#   libxcb-shape0-dev libxcb-shm0 libxcb-sync-dev libxcb-xfixes0-dev
#   libxcomposite-dev libxcomposite1 libxcursor-dev libxcursor1 libxdamage-dev
#   libxdamage1 libxext-dev libxfixes-dev libxfixes3 libxfont-dev libxfont2
#   libxi-dev libxi6 libxinerama-dev libxinerama1 libxkbcommon-dev libxkbcommon0
#   libxkbfile-dev libxkbfile1 libxmu-dev libxmu-headers libxmu6 libxmuu-dev
#   libxmuu1 libxpm-dev libxpm4 libxrandr-dev libxrandr2 libxres-dev libxres1
#   libxshmfence-dev libxss-dev libxt-dev libxt6 libxtst-dev libxtst6 libxv-dev
#   libxv1 libxvidcore4 libxvmc-dev libxvmc1 libxxf86dga-dev libxxf86dga1
#   libxxf86vm-dev libxxf86vm1 libzvbi-common libzvbi0 mesa-common-dev
#   mesa-va-drivers mesa-vdpau-drivers mir-client-platform-mesa-dev
#   mpi-default-bin mpi-default-dev ocl-icd-libopencl1 openmpi-bin
#   openmpi-common shared-mime-info swig3.0 va-driver-all vdpau-driver-all
#   x11-xkb-utils x11proto-composite-dev x11proto-damage-dev x11proto-dri2-dev
#   x11proto-fixes-dev x11proto-fonts-dev x11proto-gl-dev x11proto-input-dev
#   x11proto-randr-dev x11proto-record-dev x11proto-render-dev
#   x11proto-resource-dev x11proto-scrnsaver-dev x11proto-xext-dev
#   x11proto-xf86bigfont-dev x11proto-xf86dga-dev x11proto-xf86vidmode-dev
#   x11proto-xinerama-dev xauth xfonts-base xfonts-encodings xfonts-utils
#   xkb-data xserver-common xserver-xorg-dev
# Suggested packages:
#   cmake-doc ninja-build ffmpeg-doc i965-va-driver-shaders lrzip
#   libasound2-plugins alsa-utils libasound2-doc libbluray-bdj libboost-doc
#   graphviz libboost1.65-doc gccxml libmpfrc++-dev libntl-dev xsltproc doxygen
#   docbook-xml docbook-xsl default-jdk fop firmware-crystalhd libfftw3-bin
#   libfftw3-dev libhwloc-contrib-plugins libice-doc jackd2 libtool-doc
#   libportaudio2 openmpi-doc opus-tools pciutils pulseaudio libraw1394-doc
#   librsvg2-bin lm-sensors libsm-doc sndiod speex autoconf automaken gcj-jdk
#   libxaw-doc libxext-doc libxt-doc python-nose python-numpy-dbg
#   python-numpy-doc libgle3 swig-doc swig-examples swig3.0-examples swig3.0-doc
#   libvdpau-va-gl1 nvidia-vdpau-driver nvidia-legacy-340xx-vdpau-driver
# The following NEW packages will be installed:
#   autotools-dev cmake cmake-data ffmpeg file fontconfig freeglut3
#   gir1.2-ibus-1.0 i965-va-driver ibverbs-providers libaacs0 libarchive13
#   libasound2 libasound2-data libasound2-dev libass9 libasyncns0 libavc1394-0
#   libavcodec57 libavdevice57 libavfilter6 libavformat57 libavresample3
#   libavutil55 libbdplus0 libbluray2 libboost-all-dev libboost-atomic-dev
#   libboost-atomic1.65-dev libboost-atomic1.65.1 libboost-chrono-dev
#   libboost-chrono1.65-dev libboost-chrono1.65.1 libboost-container-dev
#   libboost-container1.65-dev libboost-container1.65.1 libboost-context-dev
#   libboost-context1.65-dev libboost-context1.65.1 libboost-coroutine-dev
#   libboost-coroutine1.65-dev libboost-coroutine1.65.1 libboost-date-time-dev
#   libboost-date-time1.65-dev libboost-date-time1.65.1 libboost-dev
#   libboost-exception-dev libboost-exception1.65-dev libboost-fiber-dev
#   libboost-fiber1.65-dev libboost-fiber1.65.1 libboost-filesystem-dev
#   libboost-filesystem1.65-dev libboost-filesystem1.65.1 libboost-graph-dev
#   libboost-graph-parallel-dev libboost-graph-parallel1.65-dev
#   libboost-graph-parallel1.65.1 libboost-graph1.65-dev libboost-graph1.65.1
#   libboost-iostreams-dev libboost-iostreams1.65-dev libboost-iostreams1.65.1
#   libboost-locale-dev libboost-locale1.65-dev libboost-locale1.65.1
#   libboost-log-dev libboost-log1.65-dev libboost-log1.65.1 libboost-math-dev
#   libboost-math1.65-dev libboost-math1.65.1 libboost-mpi-dev
#   libboost-mpi-python-dev libboost-mpi-python1.65-dev
#   libboost-mpi-python1.65.1 libboost-mpi1.65-dev libboost-mpi1.65.1
#   libboost-numpy-dev libboost-numpy1.65-dev libboost-numpy1.65.1
#   libboost-program-options-dev libboost-program-options1.65-dev
#   libboost-program-options1.65.1 libboost-python-dev libboost-python1.65-dev
#   libboost-python1.65.1 libboost-random-dev libboost-random1.65-dev
#   libboost-random1.65.1 libboost-regex-dev libboost-regex1.65-dev
#   libboost-regex1.65.1 libboost-serialization-dev
#   libboost-serialization1.65-dev libboost-serialization1.65.1
#   libboost-signals-dev libboost-signals1.65-dev libboost-signals1.65.1
#   libboost-stacktrace-dev libboost-stacktrace1.65-dev
#   libboost-stacktrace1.65.1 libboost-system-dev libboost-system1.65-dev
#   libboost-system1.65.1 libboost-test-dev libboost-test1.65-dev
#   libboost-test1.65.1 libboost-thread-dev libboost-thread1.65-dev
#   libboost-thread1.65.1 libboost-timer-dev libboost-timer1.65-dev
#   libboost-timer1.65.1 libboost-tools-dev libboost-type-erasure-dev
#   libboost-type-erasure1.65-dev libboost-type-erasure1.65.1 libboost-wave-dev
#   libboost-wave1.65-dev libboost-wave1.65.1 libboost1.65-dev
#   libboost1.65-tools-dev libbs2b0 libcaca0 libcairo2 libcapnp-0.6.1
#   libcdio-cdda2 libcdio-paranoia2 libcdio17 libchromaprint1 libcroco3
#   libcrystalhd3 libdatrie1 libdbus-1-dev libdc1394-22 libdmx-dev libdmx1
#   libdrm-amdgpu1 libdrm-dev libdrm-intel1 libdrm-nouveau2 libdrm-radeon1
#   libegl1-mesa-dev libfabric1 libfftw3-double3 libflac8 libflite1
#   libfontenc-dev libfontenc1 libfribidi0 libfs-dev libfs6 libgdk-pixbuf2.0-0
#   libgdk-pixbuf2.0-bin libgdk-pixbuf2.0-common libgl1 libgl1-mesa-dev
#   libgl1-mesa-dri libgles1 libgles2-mesa-dev libglu1-mesa libglu1-mesa-dev
#   libglvnd-core-dev libglvnd-dev libglx-mesa0 libglx0 libgme0 libgsm1
#   libhwloc-dev libhwloc-plugins libhwloc5 libibus-1.0-5 libibus-1.0-dev
#   libibverbs-dev libibverbs1 libice-dev libiec61883-0 libjack-jackd2-0
#   libjbig0 libjsoncpp1 libllvm6.0 libltdl-dev libltdl7 liblzo2-2 libmagic-mgc
#   libmagic1 libmirclient-dev libmirclient9 libmircommon-dev libmircommon7
#   libmircookie-dev libmircookie2 libmircore-dev libmircore1 libmirprotobuf3
#   libmp3lame0 libmpg123-0 libmysofa0 libnl-3-200 libnl-route-3-200 libnuma-dev
#   libnuma1 libogg0 libopenal-data libopenal1 libopenjp2-7 libopenmpi-dev
#   libopenmpi2 libopenmpt0 libopus0 libpango-1.0-0 libpangocairo-1.0-0
#   libpangoft2-1.0-0 libpciaccess-dev libpciaccess0 libpixman-1-0
#   libpixman-1-dev libpostproc54 libprotobuf-dev libprotobuf-lite10
#   libprotobuf10 libpsm-infinipath1 libpulse-dev libpulse-mainloop-glib0
#   libpulse0 libraw1394-11 librdmacm1 librhash0 librsvg2-2 librsvg2-common
#   librubberband2 libsamplerate0 libsdl2-2.0-0 libsdl2-dev libsensors4
#   libshine3 libslang2 libsm-dev libsnappy1v5 libsndfile1 libsndio-dev
#   libsndio6.1 libsoxr0 libspeex1 libssh-gcrypt-4 libswresample2 libswscale4
#   libthai-data libthai0 libtheora0 libtiff5 libtool libtwolame0 libudev-dev
#   libusb-1.0-0 libuv1 libva-drm2 libva-x11-2 libva2 libvdpau1 libvorbis0a
#   libvorbisenc2 libvorbisfile3 libvpx5 libwavpack1 libwayland-bin
#   libwayland-cursor0 libwayland-dev libwayland-egl1-mesa libwebp6 libwebpmux3
#   libwrap0 libx11-xcb-dev libx264-152 libx265-146 libxaw7 libxaw7-dev
#   libxcb-dri2-0-dev libxcb-dri3-dev libxcb-glx0 libxcb-glx0-dev
#   libxcb-present-dev libxcb-randr0 libxcb-randr0-dev libxcb-render0
#   libxcb-render0-dev libxcb-shape0 libxcb-shape0-dev libxcb-shm0
#   libxcb-sync-dev libxcb-xfixes0-dev libxcomposite-dev libxcomposite1
#   libxcursor-dev libxcursor1 libxdamage-dev libxdamage1 libxext-dev
#   libxfixes-dev libxfixes3 libxfont-dev libxfont2 libxi-dev libxi6
#   libxinerama-dev libxinerama1 libxkbcommon-dev libxkbcommon0 libxkbfile-dev
#   libxkbfile1 libxmu-dev libxmu-headers libxmu6 libxmuu-dev libxmuu1
#   libxpm-dev libxpm4 libxrandr-dev libxrandr2 libxres-dev libxres1
#   libxshmfence-dev libxss-dev libxt-dev libxt6 libxtst-dev libxtst6 libxv-dev
#   libxv1 libxvidcore4 libxvmc-dev libxvmc1 libxxf86dga-dev libxxf86dga1
#   libxxf86vm-dev libxxf86vm1 libzvbi-common libzvbi0 mesa-common-dev
#   mesa-va-drivers mesa-vdpau-drivers mir-client-platform-mesa-dev
#   mpi-default-bin mpi-default-dev ocl-icd-libopencl1 openmpi-bin
#   openmpi-common python-numpy python-opengl shared-mime-info swig swig3.0
#   va-driver-all vdpau-driver-all x11-xkb-utils x11proto-composite-dev
#   x11proto-damage-dev x11proto-dri2-dev x11proto-fixes-dev x11proto-fonts-dev
#   x11proto-gl-dev x11proto-input-dev x11proto-randr-dev x11proto-record-dev
#   x11proto-render-dev x11proto-resource-dev x11proto-scrnsaver-dev
#   x11proto-xext-dev x11proto-xf86bigfont-dev x11proto-xf86dga-dev
#   x11proto-xf86vidmode-dev x11proto-xinerama-dev xauth xfonts-base
#   xfonts-encodings xfonts-utils xkb-data xorg-dev xserver-common
#   xserver-xorg-dev xvfb
# 0 upgraded, 382 newly installed, 0 to remove and 4 not upgraded.
# Need to get 106 MB of archives.
# After this operation, 674 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 fontconfig amd64 2.12.6-0ubuntu2 [169 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libdmx1 amd64 1:1.1.3-1 [10.4 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 liblzo2-2 amd64 2.08-1.2 [48.7 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 libogg0 amd64 1.3.2-1 [17.2 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxinerama1 amd64 2:1.1.3-1 [7,908 B]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxxf86dga1 amd64 2:1.1.4-1 [13.7 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxxf86vm1 amd64 1:1.1.4-1 [10.6 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic-mgc amd64 1:5.32-2ubuntu0.1 [184 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic1 amd64 1:5.32-2ubuntu0.1 [68.4 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 file amd64 1:5.32-2ubuntu0.1 [22.1 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfribidi0 amd64 0.19.7-2 [24.9 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 libslang2 amd64 2.3.1a-3ubuntu1 [424 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 shared-mime-info amd64 1.9-2 [426 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 xkb-data all 2.23.1-1ubuntu1 [325 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 libnuma1 amd64 2.0.11-2.1 [21.6 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/main amd64 libusb-1.0-0 amd64 2:1.0.21-2 [43.3 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxmuu1 amd64 2:1.1.2-2 [9,674 B]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 xauth amd64 1:1.0.10-1 [24.6 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 autotools-dev all 20180224.1 [39.6 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic/main amd64 cmake-data all 3.10.2-1ubuntu2 [1,331 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libarchive13 amd64 3.2.2-3.1ubuntu0.1 [289 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjsoncpp1 amd64 1.7.4-3 [73.6 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic/main amd64 librhash0 amd64 1.3.6-2 [78.1 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/main amd64 libuv1 amd64 1.18.0-3 [64.4 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic/main amd64 cmake amd64 3.10.2-1ubuntu2 [3,138 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libva2 amd64 2.1.0-3 [47.6 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libva-drm2 amd64 2.1.0-3 [6,880 B]
# Get:28 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxfixes3 amd64 1:5.0.3-1 [10.8 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libva-x11-2 amd64 2.1.0-3 [11.5 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic/main amd64 libvdpau1 amd64 1.1.1-3ubuntu1 [25.5 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libavutil55 amd64 7:3.4.4-0ubuntu0.18.04.1 [190 kB]
# Get:32 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpixman-1-0 amd64 0.34.0-2 [229 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcb-render0 amd64 1.13-1 [14.7 kB]
# Get:34 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcb-shm0 amd64 1.13-1 [5,572 B]
# Get:35 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcairo2 amd64 1.15.10-2 [580 kB]
# Get:36 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libcrystalhd3 amd64 1:0.0~git20110715.fdd2f19-12 [45.8 kB]
# Get:37 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgsm1 amd64 1.0.13-4build1 [22.4 kB]
# Get:38 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmp3lame0 amd64 3.100-2 [136 kB]
# Get:39 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopenjp2-7 amd64 2.3.0-1 [145 kB]
# Get:40 http://archive.ubuntu.com/ubuntu bionic/main amd64 libopus0 amd64 1.1.2-1ubuntu1 [159 kB]
# Get:41 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcroco3 amd64 0.6.12-2 [81.3 kB]
# Get:42 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjbig0 amd64 2.1-3.1build1 [26.7 kB]
# Get:43 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtiff5 amd64 4.0.9-5 [152 kB]
# Get:44 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgdk-pixbuf2.0-common all 2.36.11-2 [4,536 B]
# Get:45 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgdk-pixbuf2.0-0 amd64 2.36.11-2 [165 kB]
# Get:46 http://archive.ubuntu.com/ubuntu bionic/main amd64 libthai-data all 0.1.27-2 [133 kB]
# Get:47 http://archive.ubuntu.com/ubuntu bionic/main amd64 libdatrie1 amd64 0.2.10-7 [17.8 kB]
# Get:48 http://archive.ubuntu.com/ubuntu bionic/main amd64 libthai0 amd64 0.1.27-2 [18.0 kB]
# Get:49 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpango-1.0-0 amd64 1.40.14-1ubuntu0.1 [153 kB]
# Get:50 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpangoft2-1.0-0 amd64 1.40.14-1ubuntu0.1 [33.2 kB]
# Get:51 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpangocairo-1.0-0 amd64 1.40.14-1ubuntu0.1 [20.8 kB]
# Get:52 http://archive.ubuntu.com/ubuntu bionic/main amd64 librsvg2-2 amd64 2.40.20-2 [98.6 kB]
# Get:53 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libshine3 amd64 3.1.1-1 [22.9 kB]
# Get:54 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsnappy1v5 amd64 1.1.7-1 [16.0 kB]
# Get:55 http://archive.ubuntu.com/ubuntu bionic/main amd64 libspeex1 amd64 1.2~rc1.2-1ubuntu2 [52.1 kB]
# Get:56 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsoxr0 amd64 0.1.2-3 [65.9 kB]
# Get:57 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libswresample2 amd64 7:3.4.4-0ubuntu0.18.04.1 [55.2 kB]
# Get:58 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtheora0 amd64 1.1.1+dfsg.1-14 [170 kB]
# Get:59 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtwolame0 amd64 0.3.13-3 [46.7 kB]
# Get:60 http://archive.ubuntu.com/ubuntu bionic/main amd64 libvorbis0a amd64 1.3.5-4.2 [86.4 kB]
# Get:61 http://archive.ubuntu.com/ubuntu bionic/main amd64 libvorbisenc2 amd64 1.3.5-4.2 [70.7 kB]
# Get:62 http://archive.ubuntu.com/ubuntu bionic/main amd64 libvpx5 amd64 1.7.0-3 [798 kB]
# Get:63 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libwavpack1 amd64 5.1.0-2ubuntu1.1 [76.6 kB]
# Get:64 http://archive.ubuntu.com/ubuntu bionic/main amd64 libwebp6 amd64 0.6.1-2 [185 kB]
# Get:65 http://archive.ubuntu.com/ubuntu bionic/main amd64 libwebpmux3 amd64 0.6.1-2 [19.6 kB]
# Get:66 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libx264-152 amd64 2:0.152.2854+gite9a5903-2 [609 kB]
# Get:67 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libx265-146 amd64 2.6-3 [1,026 kB]
# Get:68 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libxvidcore4 amd64 2:1.3.5-1 [200 kB]
# Get:69 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libzvbi-common all 0.2.35-13 [32.1 kB]
# Get:70 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libzvbi0 amd64 0.2.35-13 [235 kB]
# Get:71 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libavcodec57 amd64 7:3.4.4-0ubuntu0.18.04.1 [4,592 kB]
# Get:72 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libasound2-data all 1.1.3-5ubuntu0.1 [36.3 kB]
# Get:73 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libasound2 amd64 1.1.3-5ubuntu0.1 [359 kB]
# Get:74 http://archive.ubuntu.com/ubuntu bionic/main amd64 libraw1394-11 amd64 2.1.2-1 [30.7 kB]
# Get:75 http://archive.ubuntu.com/ubuntu bionic/main amd64 libavc1394-0 amd64 0.5.4-4build1 [16.1 kB]
# Get:76 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libass9 amd64 1:0.14.0-1 [88.2 kB]
# Get:77 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libbluray2 amd64 1:1.0.2-3 [141 kB]
# Get:78 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libchromaprint1 amd64 1.4.3-1 [36.8 kB]
# Get:79 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgme0 amd64 0.6.2-1 [121 kB]
# Get:80 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmpg123-0 amd64 1.25.10-1 [125 kB]
# Get:81 http://archive.ubuntu.com/ubuntu bionic/main amd64 libvorbisfile3 amd64 1.3.5-4.2 [16.0 kB]
# Get:82 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopenmpt0 amd64 0.3.6-1 [561 kB]
# Get:83 http://archive.ubuntu.com/ubuntu bionic/main amd64 libssh-gcrypt-4 amd64 0.8.0~20170825.94fa1e38-1build1 [171 kB]
# Get:84 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libavformat57 amd64 7:3.4.4-0ubuntu0.18.04.1 [949 kB]
# Get:85 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libavresample3 amd64 7:3.4.4-0ubuntu0.18.04.1 [52.6 kB]
# Get:86 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libbs2b0 amd64 3.1.0+dfsg-2.2 [10.5 kB]
# Get:87 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libflite1 amd64 2.1-release-1 [12.8 MB]
# Get:88 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libmysofa0 amd64 0.6~dfsg0-2 [37.8 kB]
# Get:89 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libpostproc54 amd64 7:3.4.4-0ubuntu0.18.04.1 [50.4 kB]
# Get:90 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfftw3-double3 amd64 3.3.7-1 [735 kB]
# Get:91 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsamplerate0 amd64 0.1.9-1 [938 kB]
# Get:92 http://archive.ubuntu.com/ubuntu bionic/universe amd64 librubberband2 amd64 1.8.1-7ubuntu2 [86.7 kB]
# Get:93 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libswscale4 amd64 7:3.4.4-0ubuntu0.18.04.1 [150 kB]
# Get:94 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libavfilter6 amd64 7:3.4.4-0ubuntu0.18.04.1 [874 kB]
# Get:95 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcaca0 amd64 0.99.beta19-2build2~gcc5.3 [202 kB]
# Get:96 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcdio17 amd64 1.0.0-2ubuntu2 [58.8 kB]
# Get:97 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcdio-cdda2 amd64 10.2+0.94+2-2build1 [17.7 kB]
# Get:98 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcdio-paranoia2 amd64 10.2+0.94+2-2build1 [17.2 kB]
# Get:99 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libdc1394-22 amd64 2.2.5-1 [77.5 kB]
# Get:100 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcb-glx0 amd64 1.13-1 [22.0 kB]
# Get:101 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxdamage1 amd64 1:1.1.4-3 [6,934 B]
# Get:102 http://archive.ubuntu.com/ubuntu bionic/main amd64 libdrm-amdgpu1 amd64 2.4.91-2 [19.0 kB]
# Get:103 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpciaccess0 amd64 0.14-1 [17.9 kB]
# Get:104 http://archive.ubuntu.com/ubuntu bionic/main amd64 libdrm-intel1 amd64 2.4.91-2 [59.8 kB]
# Get:105 http://archive.ubuntu.com/ubuntu bionic/main amd64 libdrm-nouveau2 amd64 2.4.91-2 [16.5 kB]
# Get:106 http://archive.ubuntu.com/ubuntu bionic/main amd64 libdrm-radeon1 amd64 2.4.91-2 [21.7 kB]
# Get:107 http://archive.ubuntu.com/ubuntu bionic/main amd64 libllvm6.0 amd64 1:6.0-1ubuntu2 [14.5 MB]
# Get:108 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsensors4 amd64 1:3.4.0-4 [28.8 kB]
# Get:109 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgl1-mesa-dri amd64 18.0.5-0ubuntu0~18.04.1 [6,011 kB]
# Get:110 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libglx-mesa0 amd64 18.0.5-0ubuntu0~18.04.1 [132 kB]
# Get:111 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libglx0 amd64 1.0.0-2ubuntu2.2 [28.1 kB]
# Get:112 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgl1 amd64 1.0.0-2ubuntu2.2 [84.8 kB]
# Get:113 http://archive.ubuntu.com/ubuntu bionic/main amd64 libiec61883-0 amd64 1.2.0-2 [23.5 kB]
# Get:114 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjack-jackd2-0 amd64 1.9.12~dfsg-2 [263 kB]
# Get:115 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopenal-data all 1:1.18.2-2 [102 kB]
# Get:116 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsndio6.1 amd64 1.1.0-3 [23.4 kB]
# Get:117 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopenal1 amd64 1:1.18.2-2 [266 kB]
# Get:118 http://archive.ubuntu.com/ubuntu bionic/main amd64 libasyncns0 amd64 0.8-6 [12.1 kB]
# Get:119 http://archive.ubuntu.com/ubuntu bionic/main amd64 libflac8 amd64 1.3.2-1 [213 kB]
# Get:120 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsndfile1 amd64 1.0.28-4 [169 kB]
# Get:121 http://archive.ubuntu.com/ubuntu bionic/main amd64 libwrap0 amd64 7.6.q-27 [46.3 kB]
# Get:122 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpulse0 amd64 1:11.1-1ubuntu7.1 [265 kB]
# Get:123 http://archive.ubuntu.com/ubuntu bionic/main amd64 libwayland-cursor0 amd64 1.14.0-2 [9,976 B]
# Get:124 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libwayland-egl1-mesa amd64 18.0.5-0ubuntu0~18.04.1 [7,148 B]
# Get:125 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcursor1 amd64 1:1.1.15-1 [19.8 kB]
# Get:126 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxi6 amd64 2:1.7.9-1 [29.2 kB]
# Get:127 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxkbcommon0 amd64 0.8.0-1 [97.6 kB]
# Get:128 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxrandr2 amd64 2:1.5.1-1 [18.1 kB]
# Get:129 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libsdl2-2.0-0 amd64 2.0.8+dfsg1-1ubuntu1.18.04.1 [378 kB]
# Get:130 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcb-shape0 amd64 1.13-1 [5,964 B]
# Get:131 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxv1 amd64 2:1.0.11-1 [10.7 kB]
# Get:132 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libavdevice57 amd64 7:3.4.4-0ubuntu0.18.04.1 [74.9 kB]
# Get:133 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 ffmpeg amd64 7:3.4.4-0ubuntu0.18.04.1 [1,587 kB]
# Get:134 http://archive.ubuntu.com/ubuntu bionic/universe amd64 freeglut3 amd64 2.8.1-3 [73.6 kB]
# Get:135 http://archive.ubuntu.com/ubuntu bionic/main amd64 libibus-1.0-5 amd64 1.5.17-3ubuntu4 [134 kB]
# Get:136 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-ibus-1.0 amd64 1.5.17-3ubuntu4 [66.6 kB]
# Get:137 http://archive.ubuntu.com/ubuntu bionic/main amd64 libnl-3-200 amd64 3.2.29-0ubuntu3 [52.8 kB]
# Get:138 http://archive.ubuntu.com/ubuntu bionic/main amd64 libnl-route-3-200 amd64 3.2.29-0ubuntu3 [146 kB]
# Get:139 http://archive.ubuntu.com/ubuntu bionic/main amd64 libibverbs1 amd64 17.1-1 [44.4 kB]
# Get:140 http://archive.ubuntu.com/ubuntu bionic/main amd64 ibverbs-providers amd64 17.1-1 [160 kB]
# Get:141 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libaacs0 amd64 0.9.0-1 [51.4 kB]
# Get:142 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libasound2-dev amd64 1.1.3-5ubuntu0.1 [123 kB]
# Get:143 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libbdplus0 amd64 0.1.2-2 [46.6 kB]
# Get:144 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [7,218 kB]
# Get:145 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-dev amd64 1.65.1.0ubuntu1 [3,128 B]
# Get:146 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost1.65-tools-dev amd64 1.65.1+dfsg-0ubuntu5 [1,222 kB]
# Get:147 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-tools-dev amd64 1.65.1.0ubuntu1 [3,096 B]
# Get:148 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-atomic1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [7,268 B]
# Get:149 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-atomic1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [5,160 B]
# Get:150 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-atomic-dev amd64 1.65.1.0ubuntu1 [3,224 B]
# Get:151 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-system1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [10.5 kB]
# Get:152 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-chrono1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [10.2 kB]
# Get:153 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-chrono1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [9,804 B]
# Get:154 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-chrono-dev amd64 1.65.1.0ubuntu1 [3,544 B]
# Get:155 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-container1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [43.4 kB]
# Get:156 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-container1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [41.7 kB]
# Get:157 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-container-dev amd64 1.65.1.0ubuntu1 [3,400 B]
# Get:158 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-context1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [8,336 B]
# Get:159 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-context1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [6,364 B]
# Get:160 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-context-dev amd64 1.65.1.0ubuntu1 [3,120 B]
# Get:161 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-thread1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [43.2 kB]
# Get:162 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-coroutine1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [22.6 kB]
# Get:163 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-coroutine1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [24.2 kB]
# Get:164 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-coroutine-dev amd64 1.65.1.0ubuntu1 [3,196 B]
# Get:165 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-date-time1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [20.5 kB]
# Get:166 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-serialization1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [99.3 kB]
# Get:167 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-serialization1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [137 kB]
# Get:168 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-date-time1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [26.7 kB]
# Get:169 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-date-time-dev amd64 1.65.1.0ubuntu1 [2,924 B]
# Get:170 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-exception1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [4,580 B]
# Get:171 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-exception-dev amd64 1.65.1.0ubuntu1 [2,916 B]
# Get:172 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-filesystem1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [40.3 kB]
# Get:173 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-fiber1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [108 kB]
# Get:174 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-fiber1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [121 kB]
# Get:175 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-fiber-dev amd64 1.65.1.0ubuntu1 [3,348 B]
# Get:176 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-system1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [11.8 kB]
# Get:177 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-filesystem1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [52.1 kB]
# Get:178 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-filesystem-dev amd64 1.65.1.0ubuntu1 [2,960 B]
# Get:179 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-regex1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [259 kB]
# Get:180 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-graph1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [93.4 kB]
# Get:181 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-test1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [240 kB]
# Get:182 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-test1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [289 kB]
# Get:183 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-graph1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [102 kB]
# Get:184 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-graph-dev amd64 1.65.1.0ubuntu1 [3,024 B]
# Get:185 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libpsm-infinipath1 amd64 3.3+20.604758e7-5 [174 kB]
# Get:186 http://archive.ubuntu.com/ubuntu bionic/main amd64 librdmacm1 amd64 17.1-1 [56.1 kB]
# Get:187 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libfabric1 amd64 1.5.3-1 [302 kB]
# Get:188 http://archive.ubuntu.com/ubuntu bionic/main amd64 libltdl7 amd64 2.4.6-2 [38.8 kB]
# Get:189 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libhwloc5 amd64 1.11.9-1 [105 kB]
# Get:190 http://archive.ubuntu.com/ubuntu bionic/main amd64 ocl-icd-libopencl1 amd64 2.2.11-1ubuntu1 [30.3 kB]
# Get:191 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libhwloc-plugins amd64 1.11.9-1 [12.5 kB]
# Get:192 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopenmpi2 amd64 2.1.1-8 [2,056 kB]
# Get:193 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-mpi1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [47.0 kB]
# Get:194 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-graph-parallel1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [62.3 kB]
# Get:195 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-graph-parallel1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [64.5 kB]
# Get:196 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-graph-parallel-dev amd64 1.65.1.0ubuntu1 [3,056 B]
# Get:197 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-regex1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [312 kB]
# Get:198 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-iostreams1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [29.2 kB]
# Get:199 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-iostreams1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [37.0 kB]
# Get:200 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-iostreams-dev amd64 1.65.1.0ubuntu1 [2,916 B]
# Get:201 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-locale1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [241 kB]
# Get:202 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-locale1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [329 kB]
# Get:203 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-locale-dev amd64 1.65.1.0ubuntu1 [3,248 B]
# Get:204 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-log1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [384 kB]
# Get:205 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-thread1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [49.0 kB]
# Get:206 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-log1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [553 kB]
# Get:207 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-log-dev amd64 1.65.1.0ubuntu1 [3,124 B]
# Get:208 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-math1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [311 kB]
# Get:209 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-math1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [560 kB]
# Get:210 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-math-dev amd64 1.65.1.0ubuntu1 [3,112 B]
# Get:211 http://archive.ubuntu.com/ubuntu bionic/universe amd64 openmpi-common all 2.1.1-8 [140 kB]
# Get:212 http://archive.ubuntu.com/ubuntu bionic/main amd64 libibverbs-dev amd64 17.1-1 [103 kB]
# Get:213 http://archive.ubuntu.com/ubuntu bionic/main amd64 libnuma-dev amd64 2.0.11-2.1 [32.2 kB]
# Get:214 http://archive.ubuntu.com/ubuntu bionic/main amd64 libltdl-dev amd64 2.4.6-2 [162 kB]
# Get:215 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libhwloc-dev amd64 1.11.9-1 [167 kB]
# Get:216 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopenmpi-dev amd64 2.1.1-8 [925 kB]
# Get:217 http://archive.ubuntu.com/ubuntu bionic/universe amd64 mpi-default-dev amd64 1.10 [3,888 B]
# Get:218 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-mpi1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [137 kB]
# Get:219 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-mpi-dev amd64 1.65.1.0ubuntu1 [3,004 B]
# Get:220 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-python1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [101 kB]
# Get:221 http://archive.ubuntu.com/ubuntu bionic/universe amd64 openmpi-bin amd64 2.1.1-8 [88.2 kB]
# Get:222 http://archive.ubuntu.com/ubuntu bionic/universe amd64 mpi-default-bin amd64 1.10 [3,108 B]
# Get:223 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-mpi-python1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [214 kB]
# Get:224 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-mpi-python1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [24.7 kB]
# Get:225 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-mpi-python-dev amd64 1.65.1.0ubuntu1 [3,040 B]
# Get:226 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-numpy1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [17.4 kB]
# Get:227 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-numpy1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [17.4 kB]
# Get:228 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-numpy-dev amd64 1.65.1.0ubuntu1 [2,960 B]
# Get:229 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-program-options1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [137 kB]
# Get:230 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-program-options1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [163 kB]
# Get:231 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-program-options-dev amd64 1.65.1.0ubuntu1 [2,940 B]
# Get:232 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-python1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [103 kB]
# Get:233 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-python-dev amd64 1.65.1.0ubuntu1 [3,216 B]
# Get:234 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-random1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [12.8 kB]
# Get:235 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-random1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [12.4 kB]
# Get:236 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-random-dev amd64 1.65.1.0ubuntu1 [2,924 B]
# Get:237 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-regex-dev amd64 1.65.1.0ubuntu1 [3,184 B]
# Get:238 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-serialization-dev amd64 1.65.1.0ubuntu1 [3,144 B]
# Get:239 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-signals1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [30.6 kB]
# Get:240 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-signals1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [33.1 kB]
# Get:241 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-signals-dev amd64 1.65.1.0ubuntu1 [2,996 B]
# Get:242 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-stacktrace1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [49.1 kB]
# Get:243 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-stacktrace1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [25.9 kB]
# Get:244 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-stacktrace-dev amd64 1.65.1.0ubuntu1 [2,924 B]
# Get:245 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-system-dev amd64 1.65.1.0ubuntu1 [3,060 B]
# Get:246 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-test-dev amd64 1.65.1.0ubuntu1 [2,960 B]
# Get:247 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-thread-dev amd64 1.65.1.0ubuntu1 [2,948 B]
# Get:248 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-timer1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [11.9 kB]
# Get:249 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-timer1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [11.8 kB]
# Get:250 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-timer-dev amd64 1.65.1.0ubuntu1 [3,044 B]
# Get:251 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-type-erasure1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [20.7 kB]
# Get:252 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-type-erasure1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [20.1 kB]
# Get:253 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-type-erasure-dev amd64 1.65.1.0ubuntu1 [3,024 B]
# Get:254 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-wave1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [178 kB]
# Get:255 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-wave1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [234 kB]
# Get:256 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-wave-dev amd64 1.65.1.0ubuntu1 [2,952 B]
# Get:257 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-all-dev amd64 1.65.1.0ubuntu1 [2,340 B]
# Get:258 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcapnp-0.6.1 amd64 0.6.1-1ubuntu1 [658 kB]
# Get:259 http://archive.ubuntu.com/ubuntu bionic/main amd64 libdbus-1-dev amd64 1.12.2-1ubuntu1 [165 kB]
# Get:260 http://archive.ubuntu.com/ubuntu bionic/main amd64 libdmx-dev amd64 1:1.1.3-1 [34.4 kB]
# Get:261 http://archive.ubuntu.com/ubuntu bionic/main amd64 libdrm-dev amd64 2.4.91-2 [238 kB]
# Get:262 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libglvnd-core-dev amd64 1.0.0-2ubuntu2.2 [12.9 kB]
# Get:263 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgles1 amd64 1.0.0-2ubuntu2.2 [11.2 kB]
# Get:264 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libglvnd-dev amd64 1.0.0-2ubuntu2.2 [3,408 B]
# Get:265 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-dri2-dev all 2018.4-4 [2,620 B]
# Get:266 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-gl-dev all 2018.4-4 [2,612 B]
# Get:267 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-xext-dev all 2018.4-4 [2,620 B]
# Get:268 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxext-dev amd64 2:1.3.3-1 [82.1 kB]
# Get:269 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-xf86vidmode-dev all 2018.4-4 [2,632 B]
# Get:270 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxxf86vm-dev amd64 1:1.1.4-1 [13.3 kB]
# Get:271 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-fixes-dev all 1:2018.4-4 [2,620 B]
# Get:272 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxfixes-dev amd64 1:5.0.3-1 [11.0 kB]
# Get:273 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-damage-dev all 1:2018.4-4 [2,620 B]
# Get:274 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxdamage-dev amd64 1:1.1.4-3 [5,028 B]
# Get:275 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcb-glx0-dev amd64 1.13-1 [27.9 kB]
# Get:276 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcb-dri2-0-dev amd64 1.13-1 [8,476 B]
# Get:277 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcb-dri3-dev amd64 1.13-1 [7,368 B]
# Get:278 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcb-randr0 amd64 1.13-1 [16.4 kB]
# Get:279 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcb-render0-dev amd64 1.13-1 [18.4 kB]
# Get:280 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcb-randr0-dev amd64 1.13-1 [20.4 kB]
# Get:281 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcb-shape0-dev amd64 1.13-1 [7,144 B]
# Get:282 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcb-xfixes0-dev amd64 1.13-1 [11.7 kB]
# Get:283 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcb-sync-dev amd64 1.13-1 [10.6 kB]
# Get:284 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcb-present-dev amd64 1.13-1 [6,968 B]
# Get:285 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxshmfence-dev amd64 1.3-1 [3,692 B]
# Get:286 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libx11-xcb-dev amd64 2:1.6.4-3ubuntu0.1 [9,764 B]
# Get:287 http://archive.ubuntu.com/ubuntu bionic/main amd64 libwayland-bin amd64 1.14.0-2 [19.0 kB]
# Get:288 http://archive.ubuntu.com/ubuntu bionic/main amd64 libwayland-dev amd64 1.14.0-2 [98.2 kB]
# Get:289 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libegl1-mesa-dev amd64 18.0.5-0ubuntu0~18.04.1 [19.8 kB]
# Get:290 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfontenc1 amd64 1:1.1.3-1 [13.9 kB]
# Get:291 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfontenc-dev amd64 1:1.1.3-1 [13.8 kB]
# Get:292 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfs6 amd64 2:1.0.7-1 [22.5 kB]
# Get:293 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-fonts-dev all 2018.4-4 [2,620 B]
# Get:294 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfs-dev amd64 2:1.0.7-1 [26.8 kB]
# Get:295 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgdk-pixbuf2.0-bin amd64 2.36.11-2 [7,864 B]
# Get:296 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgles2-mesa-dev amd64 18.0.5-0ubuntu0~18.04.1 [40.7 kB]
# Get:297 http://archive.ubuntu.com/ubuntu bionic/main amd64 libglu1-mesa amd64 9.0.0-2.1build1 [168 kB]
# Get:298 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 mesa-common-dev amd64 18.0.5-0ubuntu0~18.04.1 [536 kB]
# Get:299 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgl1-mesa-dev amd64 18.0.5-0ubuntu0~18.04.1 [4,444 B]
# Get:300 http://archive.ubuntu.com/ubuntu bionic/main amd64 libglu1-mesa-dev amd64 9.0.0-2.1build1 [206 kB]
# Get:301 http://archive.ubuntu.com/ubuntu bionic/main amd64 libibus-1.0-dev amd64 1.5.17-3ubuntu4 [145 kB]
# Get:302 http://archive.ubuntu.com/ubuntu bionic/main amd64 libice-dev amd64 2:1.0.9-2 [46.8 kB]
# Get:303 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircore1 amd64 0.31.1-0ubuntu1 [26.5 kB]
# Get:304 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircommon7 amd64 0.31.1-0ubuntu1 [73.9 kB]
# Get:305 http://archive.ubuntu.com/ubuntu bionic/main amd64 libprotobuf-lite10 amd64 3.0.0-9.1ubuntu1 [97.7 kB]
# Get:306 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmirprotobuf3 amd64 0.31.1-0ubuntu1 [127 kB]
# ...
# Setting up libxv1:amd64 (2:1.0.11-1) ...
# Setting up libxcb-glx0-dev:amd64 (1.13-1) ...
# Setting up libxxf86dga-dev:amd64 (2:1.1.4-1) ...
# Setting up libsensors4:amd64 (1:3.4.0-4) ...
# Setting up libxkbcommon0:amd64 (0.8.0-1) ...
# Setting up shared-mime-info (1.9-2) ...
# Setting up x11proto-scrnsaver-dev (2018.4-4) ...
# Setting up libboost-chrono1.65.1:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libvpx5:amd64 (1.7.0-3) ...
# Setting up libibus-1.0-5:amd64 (1.5.17-3ubuntu4) ...
# Setting up libdrm-radeon1:amd64 (2.4.91-2) ...
# Setting up libdmx1:amd64 (1:1.1.3-1) ...
# Setting up libgme0:amd64 (0.6.2-1) ...
# Setting up libthai-data (0.1.27-2) ...
# Setting up x11proto-render-dev (2:2018.4-4) ...
# Setting up libnuma-dev:amd64 (2.0.11-2.1) ...
# Setting up libbdplus0:amd64 (0.1.2-2) ...
# Setting up ocl-icd-libopencl1:amd64 (2.2.11-1ubuntu1) ...
# Setting up libxxf86vm1:amd64 (1:1.1.4-1) ...
# Setting up libzvbi0:amd64 (0.2.35-13) ...
# Setting up libva-x11-2:amd64 (2.1.0-3) ...
# Setting up libboost-program-options1.65.1:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libdrm-nouveau2:amd64 (2.4.91-2) ...
# Setting up libboost-numpy1.65.1 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libmircore1:amd64 (0.31.1-0ubuntu1) ...
# Setting up libsamplerate0:amd64 (0.1.9-1) ...
# Setting up libsndio6.1:amd64 (1.1.0-3) ...
# Setting up libnl-3-200:amd64 (3.2.29-0ubuntu3) ...
# Setting up libvorbis0a:amd64 (1.3.5-4.2) ...
# Setting up libxxf86vm-dev:amd64 (1:1.1.4-1) ...
# Setting up libprotobuf-lite10:amd64 (3.0.0-9.1ubuntu1) ...
# Setting up libxfixes-dev:amd64 (1:5.0.3-1) ...
# Setting up libboost-test1.65.1:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libmpg123-0:amd64 (1.25.10-1) ...
# Setting up libboost1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libslang2:amd64 (2.3.1a-3ubuntu1) ...
# Setting up libudev-dev:amd64 (237-3ubuntu10.3) ...
# Setting up libglvnd-core-dev:amd64 (1.0.0-2ubuntu2.2) ...
# Setting up libwayland-cursor0:amd64 (1.14.0-2) ...
# Setting up x11proto-input-dev (2018.4-4) ...
# Setting up libboost-locale1.65.1:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libgsm1:amd64 (1.0.13-4build1) ...
# Setting up libmysofa0:amd64 (0.6~dfsg0-2) ...
# Setting up x11proto-composite-dev (1:2018.4-4) ...
# Setting up libboost-random1.65.1:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libboost1.65-tools-dev (1.65.1+dfsg-0ubuntu5) ...
# Setting up libcdio17:amd64 (1.0.0-2ubuntu2) ...
# Setting up libboost-signals1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libxrandr2:amd64 (2:1.5.1-1) ...
# Setting up libxcb-sync-dev:amd64 (1.13-1) ...
# Setting up fontconfig (2.12.6-0ubuntu2) ...
# Regenerating fonts cache... done.
# Setting up liblzo2-2:amd64 (2.08-1.2) ...
# Setting up libwrap0:amd64 (7.6.q-27) ...
# Setting up libboost-math1.65.1:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libboost-regex1.65.1:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libboost-signals-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libwebp6:amd64 (0.6.1-2) ...
# Setting up libboost-locale1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libjsoncpp1:amd64 (1.7.4-3) ...
# Setting up libvorbisfile3:amd64 (1.3.5-4.2) ...
# Setting up libboost-locale-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libboost-tools-dev (1.65.1.0ubuntu1) ...
# Setting up libcairo2:amd64 (1.15.10-2) ...
# Setting up libasound2-dev:amd64 (1.1.3-5ubuntu0.1) ...
# Setting up libboost-program-options1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libxcursor-dev:amd64 (1:1.1.15-1) ...
# Setting up libxcb-randr0-dev:amd64 (1.13-1) ...
# Setting up libsm-dev:amd64 (2:1.2.2-1) ...
# Setting up libboost-stacktrace1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up gir1.2-ibus-1.0:amd64 (1.5.17-3ubuntu4) ...
# Setting up swig (3.0.12-1) ...
# Setting up libboost-atomic1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libxkbcommon-dev (0.8.0-1) ...
# Setting up libavutil55:amd64 (7:3.4.4-0ubuntu0.18.04.1) ...
# Setting up libxrandr-dev:amd64 (2:1.5.1-1) ...
# Setting up libpciaccess-dev:amd64 (0.14-1) ...
# Setting up libltdl-dev:amd64 (2.4.6-2) ...
# Setting up libboost-atomic-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libboost-test1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libxcomposite-dev:amd64 (1:0.4.4-2) ...
# Setting up libopenmpt0:amd64 (0.3.6-1) ...
# Setting up libarchive13:amd64 (3.2.2-3.1ubuntu0.1) ...
# Setting up libboost-numpy1.65-dev (1.65.1+dfsg-0ubuntu5) ...
# Setting up libmirprotobuf3:amd64 (0.31.1-0ubuntu1) ...
# Setting up libxpm-dev:amd64 (1:3.5.12-1) ...
# Setting up libflite1:amd64 (2.1-release-1) ...
# Setting up libsndio-dev:amd64 (1.1.0-3) ...
# Setting up libboost-filesystem1.65.1:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libboost-stacktrace-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up mesa-vdpau-drivers:amd64 (18.0.5-0ubuntu0~18.04.1) ...
# Setting up libdmx-dev:amd64 (1:1.1.3-1) ...
# Setting up libgdk-pixbuf2.0-0:amd64 (2.36.11-2) ...
# Setting up libprotobuf-dev:amd64 (3.0.0-9.1ubuntu1) ...
# Setting up libass9:amd64 (1:0.14.0-1) ...
# Setting up libxdamage-dev:amd64 (1:1.1.4-3) ...
# Setting up libflac8:amd64 (1.3.2-1) ...
# Setting up libgdk-pixbuf2.0-bin (2.36.11-2) ...
# Setting up libxres-dev (2:1.2.0-2) ...
# Setting up libxfont2:amd64 (1:2.0.3-1) ...
# Setting up libdc1394-22:amd64 (2.2.5-1) ...
# Setting up libcdio-cdda2:amd64 (10.2+0.94+2-2build1) ...
# Setting up libnl-route-3-200:amd64 (3.2.29-0ubuntu3) ...
# Setting up libboost-type-erasure1.65.1:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up xfonts-utils (1:7.7+6) ...
# Setting up libboost-serialization1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libthai0:amd64 (0.1.27-2) ...
# Setting up libboost-chrono1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libmircookie-dev:amd64 (0.31.1-0ubuntu1) ...
# Setting up libboost-graph1.65.1:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libxmuu-dev:amd64 (2:1.1.2-2) ...
# Setting up file (1:5.32-2ubuntu0.1) ...
# Setting up libboost-exception1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libswresample2:amd64 (7:3.4.4-0ubuntu0.18.04.1) ...
# Setting up libxss-dev:amd64 (1:1.2.2-1) ...
# Setting up libhwloc5:amd64 (1.11.9-1) ...
# Setting up libboost-log1.65.1 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libxmu6:amd64 (2:1.1.2-2) ...
# Setting up libboost-coroutine1.65.1:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libhwloc-plugins (1.11.9-1) ...
# Setting up libdrm-intel1:amd64 (2.4.91-2) ...
# Setting up libfontenc-dev:amd64 (1:1.1.3-1) ...
# Setting up libboost-exception-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libboost-random1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libibus-1.0-dev:amd64 (1.5.17-3ubuntu4) ...
# Setting up librubberband2:amd64 (1.8.1-7ubuntu2) ...
# Setting up libboost-python1.65-dev (1.65.1+dfsg-0ubuntu5) ...
# Setting up libswscale4:amd64 (7:3.4.4-0ubuntu0.18.04.1) ...
# Setting up libboost-wave1.65.1:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libwebpmux3:amd64 (0.6.1-2) ...
# Setting up mesa-va-drivers:amd64 (18.0.5-0ubuntu0~18.04.1) ...
# Setting up libboost-context1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libpango-1.0-0:amd64 (1.40.14-1ubuntu0.1) ...
# Setting up libcdio-paranoia2:amd64 (10.2+0.94+2-2build1) ...
# Setting up libxv-dev:amd64 (2:1.0.11-1) ...
# Setting up libxcb-shape0-dev:amd64 (1.13-1) ...
# Setting up libpostproc54:amd64 (7:3.4.4-0ubuntu0.18.04.1) ...
# Setting up libjack-jackd2-0:amd64 (1.9.12~dfsg-2) ...
# Setting up libboost-timer1.65.1:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libfs-dev:amd64 (2:1.0.7-1) ...
# Setting up libmircommon7:amd64 (0.31.1-0ubuntu1) ...
# Setting up libboost-context-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libopenal1:amd64 (1:1.18.2-2) ...
# Setting up libboost-test-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libboost-system1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libboost-regex1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libboost-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libxi-dev:amd64 (2:1.7.9-1) ...
# Setting up libvorbisenc2:amd64 (1.3.5-4.2) ...
# Setting up libboost-container1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libcaca0:amd64 (0.99.beta19-2build2~gcc5.3) ...
# Setting up libwayland-dev:amd64 (1.14.0-2) ...
# Setting up libboost-math1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up cmake (3.10.2-1ubuntu2) ...
# Setting up libtheora0:amd64 (1.1.1+dfsg.1-14) ...
# Setting up libboost-math-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libboost-numpy-dev (1.65.1.0ubuntu1) ...
# Setting up xfonts-base (1:1.0.4+nmu1) ...
# Setting up libboost-type-erasure1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libboost-program-options-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libboost-python-dev (1.65.1.0ubuntu1) ...
# Setting up vdpau-driver-all:amd64 (1.1.1-3ubuntu1) ...
# Setting up libtool (2.4.6-2) ...
# Setting up libxaw7:amd64 (2:1.0.13-1) ...
# Setting up libibverbs1:amd64 (17.1-1) ...
# Setting up libboost-fiber1.65.1:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libboost-serialization-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libxt-dev:amd64 (1:1.1.5-1) ...
# Setting up libboost-fiber1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libboost-coroutine1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libboost-graph1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libavresample3:amd64 (7:3.4.4-0ubuntu0.18.04.1) ...
# Setting up x11-xkb-utils (7.7+3ubuntu0.18.04.1) ...
# Setting up libhwloc-dev:amd64 (1.11.9-1) ...
# Setting up libxmu-dev:amd64 (2:1.1.2-2) ...
# Setting up libboost-date-time1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libxcb-xfixes0-dev:amd64 (1.13-1) ...
# Setting up libboost-chrono-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libxaw7-dev:amd64 (2:1.0.13-1) ...
# Setting up libboost-system-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libboost-graph-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libdrm-dev:amd64 (2.4.91-2) ...
# Setting up libgl1-mesa-dri:amd64 (18.0.5-0ubuntu0~18.04.1) ...
# Setting up libboost-type-erasure-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libxvmc-dev:amd64 (2:1.0.10-1) ...
# Setting up libmirclient9:amd64 (0.31.1-0ubuntu1) ...
# Setting up libboost-fiber-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up librdmacm1:amd64 (17.1-1) ...
# Setting up libboost-iostreams1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libboost-date-time-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libboost-filesystem1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libpangoft2-1.0-0:amd64 (1.40.14-1ubuntu0.1) ...
# Setting up libboost-container-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libxtst-dev:amd64 (2:1.2.3-1) ...
# Setting up libxfont-dev (1:2.0.3-1) ...
# Setting up libsndfile1:amd64 (1.0.28-4) ...
# Setting up i965-va-driver:amd64 (2.1.0-0ubuntu1) ...
# Setting up libboost-random-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libboost-thread1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libboost-timer1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libboost-iostreams-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libmircommon-dev:amd64 (0.31.1-0ubuntu1) ...
# Setting up va-driver-all:amd64 (2.1.0-3) ...
# Setting up ibverbs-providers:amd64 (17.1-1) ...
# Setting up libboost-regex-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libxcb-present-dev:amd64 (1.13-1) ...
# Setting up libboost-coroutine-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libibverbs-dev:amd64 (17.1-1) ...
# Setting up libglx-mesa0:amd64 (18.0.5-0ubuntu0~18.04.1) ...
# Setting up xserver-common (2:1.19.6-1ubuntu4) ...
# Setting up mesa-common-dev:amd64 (18.0.5-0ubuntu0~18.04.1) ...
# Setting up libboost-thread-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libfabric1 (1.5.3-1) ...
# Setting up libmirclient-dev:amd64 (0.31.1-0ubuntu1) ...
# Setting up libboost-wave1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libboost-timer-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libpangocairo-1.0-0:amd64 (1.40.14-1ubuntu0.1) ...
# Setting up libboost-filesystem-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libpulse0:amd64 (1:11.1-1ubuntu7.1) ...
# Setting up libboost-log1.65-dev (1.65.1+dfsg-0ubuntu5) ...
# Setting up libsdl2-2.0-0:amd64 (2.0.8+dfsg1-1ubuntu1.18.04.1) ...
# Setting up libboost-wave-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libopenmpi2:amd64 (2.1.1-8) ...
# Setting up libglx0:amd64 (1.0.0-2ubuntu2.2) ...
# Setting up mir-client-platform-mesa-dev:amd64 (0.31.1-0ubuntu1) ...
# Setting up libpulse-mainloop-glib0:amd64 (1:11.1-1ubuntu7.1) ...
# Setting up libpulse-dev:amd64 (1:11.1-1ubuntu7.1) ...
# Setting up librsvg2-2:amd64 (2.40.20-2) ...
# Setting up libboost-mpi1.65.1 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libopenmpi-dev (2.1.1-8) ...
# update-alternatives: using /usr/lib/x86_64-linux-gnu/openmpi/include to provide /usr/include/mpi (mpi) in auto mode
# update-alternatives: warning: skip creation of /usr/share/man/man1/mpicc.1.gz because associated file /usr/share/man/man1/mpicc.openmpi.1.gz (of link group mpi) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/mpic++.1.gz because associated file /usr/share/man/man1/mpic++.openmpi.1.gz (of link group mpi) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/mpicxx.1.gz because associated file /usr/share/man/man1/mpicxx.openmpi.1.gz (of link group mpi) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/mpiCC.1.gz because associated file /usr/share/man/man1/mpiCC.openmpi.1.gz (of link group mpi) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/mpif77.1.gz because associated file /usr/share/man/man1/mpif77.openmpi.1.gz (of link group mpi) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/mpif90.1.gz because associated file /usr/share/man/man1/mpif90.openmpi.1.gz (of link group mpi) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/mpifort.1.gz because associated file /usr/share/man/man1/mpifort.openmpi.1.gz (of link group mpi) doesn't exist
# Setting up libavcodec57:amd64 (7:3.4.4-0ubuntu0.18.04.1) ...
# Setting up openmpi-bin (2.1.1-8) ...
# update-alternatives: using /usr/bin/mpirun.openmpi to provide /usr/bin/mpirun (mpirun) in auto mode
# update-alternatives: warning: skip creation of /usr/share/man/man1/mpirun.1.gz because associated file /usr/share/man/man1/mpirun.openmpi.1.gz (of link group mpirun) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/mpiexec.1.gz because associated file /usr/share/man/man1/mpiexec.openmpi.1.gz (of link group mpirun) doesn't exist
# Setting up librsvg2-common:amd64 (2.40.20-2) ...
# Setting up mpi-default-dev (1.10) ...
# Setting up libboost-log-dev (1.65.1.0ubuntu1) ...
# Setting up libgl1:amd64 (1.0.0-2ubuntu2.2) ...
# Setting up libglu1-mesa:amd64 (9.0.0-2.1build1) ...
# Setting up xserver-xorg-dev (2:1.19.6-1ubuntu4) ...
# Setting up libboost-mpi1.65-dev (1.65.1+dfsg-0ubuntu5) ...
# Setting up mpi-default-bin (1.10) ...
# Setting up freeglut3:amd64 (2.8.1-3) ...
# Setting up xorg-dev (1:7.7+19ubuntu7.1) ...
# Setting up libchromaprint1:amd64 (1.4.3-1) ...
# Setting up libboost-graph-parallel1.65.1 (1.65.1+dfsg-0ubuntu5) ...
# Setting up python-opengl (3.1.0+dfsg-1) ...
# Setting up xvfb (2:1.19.6-1ubuntu4) ...
# Setting up libboost-graph-parallel1.65-dev (1.65.1+dfsg-0ubuntu5) ...
# Setting up libglvnd-dev:amd64 (1.0.0-2ubuntu2.2) ...
# Setting up libgl1-mesa-dev:amd64 (18.0.5-0ubuntu0~18.04.1) ...
# Setting up libegl1-mesa-dev:amd64 (18.0.5-0ubuntu0~18.04.1) ...
# Setting up libboost-graph-parallel-dev (1.65.1.0ubuntu1) ...
# Setting up libboost-mpi-dev (1.65.1.0ubuntu1) ...
# Setting up libavformat57:amd64 (7:3.4.4-0ubuntu0.18.04.1) ...
# Setting up libboost-mpi-python1.65.1 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libglu1-mesa-dev:amd64 (9.0.0-2.1build1) ...
# Setting up libavfilter6:amd64 (7:3.4.4-0ubuntu0.18.04.1) ...
# Setting up libgles2-mesa-dev:amd64 (18.0.5-0ubuntu0~18.04.1) ...
# Setting up libboost-mpi-python1.65-dev (1.65.1+dfsg-0ubuntu5) ...
# Setting up libboost-mpi-python-dev (1.65.1.0ubuntu1) ...
# Setting up libboost-all-dev (1.65.1.0ubuntu1) ...
# Setting up libsdl2-dev:amd64 (2.0.8+dfsg1-1ubuntu1.18.04.1) ...
# Setting up libavdevice57:amd64 (7:3.4.4-0ubuntu0.18.04.1) ...
# Setting up ffmpeg (7:3.4.4-0ubuntu0.18.04.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Processing triggers for libgdk-pixbuf2.0-0:amd64 (2.36.11-2) ...

# %%
# !pip install pyvirtualdisplay
# !pip install piglet
# Out:
# Collecting pyvirtualdisplay
#   Downloading https://files.pythonhosted.org/packages/39/37/f285403a09cc261c56b6574baace1bdcf4b8c7428c8a7239cbba137bc0eb/PyVirtualDisplay-0.2.1.tar.gz
# Collecting EasyProcess (from pyvirtualdisplay)
#   Downloading https://files.pythonhosted.org/packages/0d/f1/d2de7591e7dfc164d286fa16f051e6c0cf3141825586c3b04ae7cda7ac0f/EasyProcess-0.2.3.tar.gz
# Building wheels for collected packages: pyvirtualdisplay, EasyProcess
# done
#   Stored in directory: /root/.cache/pip/wheels/d1/8c/16/1c64227974ae29c687e4cc30fd691d5c0fd40f54446dde99da
# done
#   Stored in directory: /root/.cache/pip/wheels/b4/c6/e3/c163b04029d8fccfd54b809802640c1af587a01be8d7a04e1a
# Successfully built pyvirtualdisplay EasyProcess
# Installing collected packages: EasyProcess, pyvirtualdisplay
# Successfully installed EasyProcess-0.2.3 pyvirtualdisplay-0.2.1
# Collecting piglet
#   Downloading https://files.pythonhosted.org/packages/86/f6/ef278239ebe525466ea51a7dd9d6d3211d197ac4b4abc76e17cdd419f69c/piglet-0.4.4.tar.gz (52kB)
#     100% |████████████████████████████████| 61kB 2.3MB/s
# Collecting Parsley (from piglet)
#   Downloading https://files.pythonhosted.org/packages/2b/d6/4fed8d65e28a970e1c5cb33ce9c7e22e3de745e1b2ae37af051ef16aea3b/Parsley-1.3-py2.py3-none-any.whl (88kB)
#     100% |████████████████████████████████| 92kB 4.0MB/s
# Collecting attrs (from piglet)
#   Downloading https://files.pythonhosted.org/packages/3a/e1/5f9023cc983f1a628a8c2fd051ad19e76ff7b142a0faf329336f9a62a514/attrs-18.2.0-py2.py3-none-any.whl
# Collecting astunparse (from piglet)
#   Downloading https://files.pythonhosted.org/packages/0d/9d/1576217f67e7420f5945c15c6afd7045178c4850b148741bdbdbdabbf40e/astunparse-1.6.1-py2.py3-none-any.whl
# Requirement already satisfied: markupsafe in /usr/local/lib/python3.6/dist-packages (from piglet) (1.0)
# Requirement already satisfied: six<2.0,>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from astunparse->piglet) (1.11.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.6/dist-packages (from astunparse->piglet) (0.32.0)
# Building wheels for collected packages: piglet
# done
#   Stored in directory: /root/.cache/pip/wheels/c7/59/a5/5bd1a35a4a4596714c4c7925a1751e7b1580b6ced363fd7969
# Successfully built piglet
# Installing collected packages: Parsley, attrs, astunparse, piglet
# Successfully installed Parsley-1.3 astunparse-1.6.1 attrs-18.2.0 piglet-0.4.4

# %%
from pyvirtualdisplay import Display
display = Display(visible=0, size=(1400, 900))
display.start()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/easyprocess/__init__.py in start(self)
#     224                                           cwd=self.cwd,
# --> 225                                           env=self.env,
#     226                                           )
#
# /usr/lib/python3.6/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     708                                 errread, errwrite,
# --> 709                                 restore_signals, start_new_session)
#     710         except:
#
# /usr/lib/python3.6/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1343                             err_msg += ': ' + repr(err_filename)
# -> 1344                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1345                 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Xvfb': 'Xvfb'
#
# During handling of the above exception, another exception occurred:
#
# EasyProcessError                          Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/easyprocess/__init__.py in check_installed(self)
#     177         try:
# --> 178             self.call()
#     179         except Exception:
#
# /usr/local/lib/python3.6/dist-packages/easyprocess/__init__.py in call(self, timeout)
#     193         """
# --> 194         self.start().wait(timeout=timeout)
#     195         if self.is_alive():
#
# /usr/local/lib/python3.6/dist-packages/easyprocess/__init__.py in start(self)
#     229             self.oserror = oserror
# --> 230             raise EasyProcessError(self, 'start error')
#     231         self.is_started = True
#
# EasyProcessError: start error <EasyProcess cmd_param=['Xvfb', '-help'] cmd=['Xvfb', '-help'] oserror=[Errno 2] No such file or directory: 'Xvfb': 'Xvfb' return_code=None stdout="None" stderr="None" timeout_happened=False>
#
# During handling of the above exception, another exception occurred:
#
# EasyProcessCheckInstalledError            Traceback (most recent call last)
# <ipython-input-3-babc120eca7d> in <module>()
#       1 from pyvirtualdisplay import Display
# ----> 2 display = Display(visible=0, size=(1400, 900))
#       3 display.start()
#
# /usr/local/lib/python3.6/dist-packages/pyvirtualdisplay/display.py in __init__(self, backend, visible, size, color_depth, bgcolor, use_xauth, **kwargs)
#      32                 self.backend = 'xvfb'
#      33
# ---> 34         self._obj = self.display_class(
#      35             size=size,
#      36             color_depth=color_depth,
#
# /usr/local/lib/python3.6/dist-packages/pyvirtualdisplay/display.py in display_class(self)
#      50
#      51         # TODO: check only once
# ---> 52         cls.check_installed()
#      53
#      54         return cls
#
# /usr/local/lib/python3.6/dist-packages/pyvirtualdisplay/xvfb.py in check_installed(cls)
#      36     def check_installed(cls):
#      37         EasyProcess([PROGRAM, '-help'], url=URL,
# ---> 38                     ubuntu_package=PACKAGE).check_installed()
#      39
#      40     @property
#
# /usr/local/lib/python3.6/dist-packages/easyprocess/__init__.py in check_installed(self)
#     178             self.call()
#     179         except Exception:
# --> 180             raise EasyProcessCheckInstalledError(self)
#     181         return self
#     182
#
# EasyProcessCheckInstalledError: cmd=['Xvfb', '-help']
# OSError=[Errno 2] No such file or directory: 'Xvfb': 'Xvfb'
# Program install error!
# You can install it in terminal:
# sudo apt-get install xvfb

# %%
# !pip install gym
# !pip install "gym[atari]"
# Out:
# Requirement already satisfied: gym in /usr/local/lib/python3.6/dist-packages (0.10.8)
# Requirement already satisfied: requests>=2.0 in /usr/local/lib/python3.6/dist-packages (from gym) (2.18.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from gym) (1.11.0)
# Requirement already satisfied: pyglet>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym) (1.3.2)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.6/dist-packages (from gym) (1.14.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from gym) (0.19.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym) (3.0.4)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym) (1.22)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym) (2018.8.24)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet>=1.2.0->gym) (0.16.0)
# Requirement already satisfied: gym[atari] in /usr/local/lib/python3.6/dist-packages (0.10.8)
# Requirement already satisfied: requests>=2.0 in /usr/local/lib/python3.6/dist-packages (from gym[atari]) (2.18.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from gym[atari]) (0.19.1)
# Requirement already satisfied: pyglet>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym[atari]) (1.3.2)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from gym[atari]) (1.11.0)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.6/dist-packages (from gym[atari]) (1.14.6)
# Requirement already satisfied: Pillow; extra == "atari" in /usr/local/lib/python3.6/dist-packages (from gym[atari]) (4.0.0)
# Collecting atari-py>=0.1.4; extra == "atari" (from gym[atari])
#   Downloading https://files.pythonhosted.org/packages/16/cc/aabbe1580df0f9b22851e210d5e35e3faa305d10a8783997fb8e79239dbc/atari_py-0.1.6-py3-none-manylinux1_x86_64.whl (1.7MB)
#     100% |████████████████████████████████| 1.7MB 8.0MB/s
# Collecting PyOpenGL; extra == "atari" (from gym[atari])
#   Downloading https://files.pythonhosted.org/packages/9c/1d/4544708aaa89f26c97cc09450bb333a23724a320923e74d73e028b3560f9/PyOpenGL-3.1.0.tar.gz (1.2MB)
#     100% |████████████████████████████████| 1.2MB 10.4MB/s
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym[atari]) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym[atari]) (2018.8.24)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym[atari]) (3.0.4)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym[atari]) (1.22)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet>=1.2.0->gym[atari]) (0.16.0)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from Pillow; extra == "atari"->gym[atari]) (0.46)
# Building wheels for collected packages: PyOpenGL
# done
#   Stored in directory: /root/.cache/pip/wheels/6c/00/7f/1dd736f380848720ad79a1a1de5272e0d3f79c15a42968fb58
# Successfully built PyOpenGL
# Installing collected packages: atari-py, PyOpenGL
# Successfully installed PyOpenGL-3.1.0 atari-py-0.1.6

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# This code creates a virtual display to draw game images on. 
# If you are running locally, just ignore it
import os
if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY"))==0:
    # !bash ../xvfb start
    # %env DISPLAY=:1

# %%
import gym
env = gym.make("MountainCar-v0")

plt.imshow(env.render('rgb_array'))
print("Observation space:", env.observation_space)
print("Action space:", env.action_space)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Observation space: Box(2,)
# Action space: Discrete(3)

# %%
obs0 = env.reset()
print("initial observation code:", obs0)
# Out:
# initial observation code: [-0.46060213  0.        ]

# %%
print("taking action 2 (right)")
new_obs, reward, is_done, _ = env.step(2)

print("new observation code:", new_obs)
print("reward:", reward)
print("is game over?:", is_done)

# Note: as you can see, the car has moved to the riht slightly (around 0.0005)
# Out:
# taking action 2 (right)
# new observation code: [-4.39540092e-01  3.78973367e-04]
# reward: -1.0
# is game over?: False

# %%
# create env manually to set time limit. Please don't change this.
TIME_LIMIT = 250
env = gym.wrappers.TimeLimit(gym.envs.classic_control.MountainCarEnv(),
                             max_episode_steps=TIME_LIMIT + 1)
s = env.reset()
actions = {'left': 0, 'stop': 1, 'right': 2}

# prepare "display"
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_subplot(111)
fig.show()
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# <div id='a0aca647-8eea-4d9f-9954-b51fcea9b7da'></div>

# %%
def policy(t):
    if t>50 and t<100:
        return actions['left']
    else:
        return actions['right']

# %%
for t in range(TIME_LIMIT):
    
    # change the line below to reach the flag
    s, r, done, _ = env.step(policy(t))
    
    #draw game image on display
    ax.clear()
    ax.imshow(env.render('rgb_array'))
    fig.canvas.draw()
    
    if done:
        print("Well done!")
        break
else:    
    print("Time limit exceeded. Try again.")

# %% [markdown]
# #2

# %% [markdown]
# 遺伝的手法による強化学習

# %%
import gym
import numpy as np, pandas as pd

env = gym.make("Taxi-v2")
env.reset()
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %%
n_states = env.observation_space.n
n_actions = env.action_space.n

print("n_states=%i, n_actions=%i"%(n_states, n_actions))
# Out:
# n_states=500, n_actions=6

# %%
policy = np.ones((n_states, n_actions))/n_actions

# %%
def generate_session(policy,t_max=10**4):
    """
    Play game until end or for t_max ticks.
    :param policy: an array of shape [n_states,n_actions] with action probabilities
    :returns: list of states, list of actions and sum of rewards
    """
    states,actions = [],[]
    total_reward = 0.
    
    s = env.reset()
    
    for t in range(t_max):
        
        a = np.random.choice(n_actions, 1, p=policy[s])[0]
        
        new_s, r, done, info = env.step(a)
        
        #Record state, action and add up reward to states,actions and total_reward accordingly. 
        states.append(s)
        actions.append(a)
        total_reward += r
        
        s = new_s
        if done:
            break
    return states, actions, total_reward

# %%
s,a,r = generate_session(policy)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

sample_rewards = [generate_session(policy,t_max=1000)[-1] for _ in range(200)]

plt.hist(sample_rewards,bins=20);
plt.vlines([np.percentile(sample_rewards, 50)], [0], [100], label="50'th percentile", color='green')
plt.vlines([np.percentile(sample_rewards, 90)], [0], [100], label="90'th percentile", color='red')
plt.legend()

# %%
def select_elites(states_batch,actions_batch,rewards_batch,percentile=50):
    """
    Select states and actions from games that have rewards >= percentile
    :param states_batch: list of lists of states, states_batch[session_i][t]
    :param actions_batch: list of lists of actions, actions_batch[session_i][t]
    :param rewards_batch: list of rewards, rewards_batch[session_i][t]
    
    :returns: elite_states,elite_actions, both 1D lists of states and respective actions from elite sessions
    
    Please return elite states and actions in their original order 
    [i.e. sorted by session number and timestep within session]
    
    If you're confused, see examples below. Please don't assume that states are integers (they'll get different later).
    """
    
    reward_threshold = np.percentile(rewards_batch, percentile)
    
    elite_states  = [s for i in range(len(states_batch)) if rewards_batch[i]>=reward_threshold for s in states_batch[i]]
    elite_actions = [a for i in range(len(actions_batch)) if rewards_batch[i]>=reward_threshold for a in actions_batch[i]]
    
    return elite_states,elite_actions

# %%
from collections import defaultdict
def update_policy(elite_states,elite_actions):
    """
    Given old policy and a list of elite states/actions from select_elites,
    return new updated policy where each action probability is proportional to
    
    policy[s_i,a_i] ~ #[occurences of si and ai in elite states/actions]
    
    Don't forget to normalize policy to get valid probabilities and handle 0/0 case.
    In case you never visited a state, set probabilities for all actions to 1./n_actions
    
    :param elite_states: 1D list of states from elite sessions
    :param elite_actions: 1D list of actions from elite sessions
    
    """
    
    new_policy = np.zeros([n_states,n_actions])
    
    #Don't forget to set 1/n_actions for all actions in unvisited states.
    state_action_dict = defaultdict(lambda: [0]*n_actions)
    for i in range(len(elite_states)):
        state_action_dict[elite_states[i]][elite_actions[i]]+=1
    for i in range(n_states):
        if i not in state_action_dict:
            new_policy[i] = [1/n_actions]*n_actions
        else:
            new_policy[i] = [p/sum(state_action_dict[i]) for p in state_action_dict[i]]
    
    
    return new_policy

# %%
from IPython.display import clear_output

def show_progress(batch_rewards, log, percentile, reward_range=[-990,+10]):
    """
    A convenience function that displays training progress. 
    No cool math here, just charts.
    """
    
    mean_reward, threshold = np.mean(batch_rewards), np.percentile(batch_rewards, percentile)
    log.append([mean_reward,threshold])

    clear_output(True)
    print("mean reward = %.3f, threshold=%.3f"%(mean_reward, threshold))
    plt.figure(figsize=[8,4])
    plt.subplot(1,2,1)
    plt.plot(list(zip(*log))[0], label='Mean rewards')
    plt.plot(list(zip(*log))[1], label='Reward thresholds')
    plt.legend()
    plt.grid()
    
    plt.subplot(1,2,2)
    plt.hist(batch_rewards,range=reward_range);
    plt.vlines([np.percentile(batch_rewards, percentile)], [0], [100], label="percentile", color='red')
    plt.legend()
    plt.grid()

    plt.show()

# %%
policy = np.ones([n_states, n_actions]) / n_actions

# %%
n_sessions = 250  #sample this many sessions
percentile = 50  #take this percent of session with highest rewards
learning_rate = 0.5  #add this thing to all counts for stability

log = []

for i in range(100):
    
    sessions = [generate_session(policy) for _ in range(n_sessions)]
    
    batch_states,batch_actions,batch_rewards = zip(*sessions)

    elite_states, elite_actions = select_elites(batch_states,batch_actions,batch_rewards,percentile)
    
    new_policy = update_policy(elite_states,elite_actions)
    
    policy = learning_rate * new_policy + (1-learning_rate) * policy
    
    #display results on chart
    show_progress(batch_rewards, log, percentile)
# Out:
# mean reward = -34.892, threshold=6.000
